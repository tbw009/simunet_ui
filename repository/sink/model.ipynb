# %% [markdown]
# # Sink (balance border)
#
# The sink represents a balance border for outgoing flows.
#
# <img src = "./model.svg" width=100px>
#
# ## Model equations
#
# There are no model equations for the sink. All variables of the port entering the sink are copied by the waveform algorithm.
#
# ## Parameters
#
# There are no parameters for the model.

# %% [markdown]
# ## Implementation of the model

# %%
from simunetcore import Model
import copy

# Model implementation for the Sink
class Sink(Model):
    def __init__(self, name=""):
        Model.__init__(self, name)
        
        # Model endpoint
        self.site = "local"
        self.threadsafe = True
        
    def compute(self, *args, **kwargs):
        # The sink has no output, nothing to do here
        pass
